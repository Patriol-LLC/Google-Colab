# %% [markdown]
# <a href="https://colab.research.google.com/github/Patriol-LLC/Google-Colab/blob/main/HTTP_Traffic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
http = pd.read_csv('/content/drive/MyDrive/Colab Data/HTTP Traffic.csv', index_col=0)

# %%
http.head()
# Out:
#                            Source   Destination Protocol  Length  \
# Time
# 2022-10-12 18:52:47     127.0.0.1  81.95.105.80     HTTP     143
# 2022-10-12 18:52:47  81.95.105.80     127.0.0.1     HTTP     390
# 2022-10-12 18:53:01     127.0.0.1  168.167.2.74     HTTP     473
# 2022-10-12 18:53:02  168.167.2.74     127.0.0.1     HTTP     353
# 2022-10-12 18:53:02     127.0.0.1  168.167.2.74     HTTP    1185
#
#                                     Host  \
# Time
# 2022-10-12 18:52:47     www.netresec.com
# 2022-10-12 18:52:47                  NaN
# 2022-10-12 18:53:01  aefd.nelreports.net
# 2022-10-12 18:53:02                  NaN
# 2022-10-12 18:53:02  aefd.nelreports.net
#
#                                                                   Info
# Time
# 2022-10-12 18:52:47             GET /updatecheck.ashx?l=1273 HTTP/1.1
# 2022-10-12 18:52:47                       HTTP/1.1 200 OK  (text/html)
# 2022-10-12 18:53:01           OPTIONS /api/report?cat=bingth HTTP/1.1
# ...

# %%
sns.displot(http['Host']);
plt.xticks(rotation=90);

# %%
sns.barplot(data=http, x="Length", y="Host")

# %%
sns.scatterplot(data=http, x="Host", y="Destination");
plt.xticks(rotation=90);

# %%
sns.scatterplot(data=http, x="Host", y="Length");
plt.xticks(rotation=90);
