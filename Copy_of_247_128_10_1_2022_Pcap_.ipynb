# %% [markdown]
# <a href="https://colab.research.google.com/github/Patriol-LLC/Google-Colab/blob/main/Copy_of_247_128_10_1_2022_Pcap_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ipdata
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import ipdata
ipdata.api_key = "e011773a37297a18eb7aef5e093cb9e8e468afb1db5fdd122438ab4e"
print('Success')
# Out:
# Success

# %%
net_data = pd.read_csv('/content/247-142-128.csv')
net_data.head()
# Out:
#                   Time         Source  Source Port      Destination  \
# 0  2022-10-01 11:49:19  10.10.139.201        50306   172.217.170.40
# 1  2022-10-01 11:49:19  10.10.139.201        50307     54.247.55.65
# 2  2022-10-01 11:49:23  10.10.139.201        50305     54.247.55.65
# 3  2022-10-01 11:49:23  10.10.139.201        50308  172.217.170.106
# 4  2022-10-01 11:49:23  10.10.139.201        50309   172.217.170.10
#
#    Destination Port Protocol                          Server Name  \
# 0               443    TLSv1             www.googletagmanager.com
# 1               443    TLSv1                sn.webrootcloudav.com
# 2               443    TLSv1                sn.webrootcloudav.com
# 3               443  TLSv1.3           cloudsearch.googleapis.com
# 4               443  TLSv1.3  optimizationguide-pa.googleapis.com
#
#            Info
# 0  Client Hello
# 1  Client Hello
# 2  Client Hello
# 3  Client Hello
# 4  Client Hello

# %%
plt.figure(figsize=(20,10));
sns.lineplot(data = net_data, x=net_data['Time'] , y=net_data['Server Name']);

plt.xticks(
    rotation=45, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
);

plt.yticks(
    rotation=0, 
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
);

plt.title('Trends in Server Usage Against Time')
# Out:
# Text(0.5, 1.0, 'Trends in Server Usage Against Time')

# %%
all_traffic = pd.read_csv('/content/247-142-128-Entire-Network.csv', index_col=0)
all_traffic.head()
# Out:
#                                         Source  Source Port Destination  \
# Time
# 2022-10-01 11:49:18  fe80::ec86:bd5c:f32a:7ac5       1900.0     ff02::c
# 2022-10-01 11:49:18  fe80::ec86:bd5c:f32a:7ac5       1900.0     ff02::c
# 2022-10-01 11:49:18  fe80::ec86:bd5c:f32a:7ac5       1900.0     ff02::c
# 2022-10-01 11:49:18              Dell_e8:e8:d6          NaN   Broadcast
# 2022-10-01 11:49:18             Cisco_7a:18:80          NaN   Broadcast
#
#                      Destination Port Protocol Server Name  \
# Time
# 2022-10-01 11:49:18            1900.0     SSDP         NaN
# 2022-10-01 11:49:18            1900.0     SSDP         NaN
# 2022-10-01 11:49:18            1900.0     SSDP         NaN
# 2022-10-01 11:49:18               NaN      ARP         NaN
# 2022-10-01 11:49:18               NaN      ARP         NaN
#
#                                                           Info
# Time
# 2022-10-01 11:49:18                         NOTIFY * HTTP/1.1
# ...

# %%
source = all_traffic.groupby('Source').Source.unique()
source.describe()
# Out:
# count                 211
# unique                211
# top       [10.10.136.173]
# freq                    1
# Name: Source, dtype: object

# %%
plt.figure(figsize=(10,10));
sns.histplot(all_traffic['Protocol']);
plt.xticks(
    rotation=45,
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
);

# %%
plt.figure(figsize=(80,10));
sns.histplot(all_traffic['Source']);
plt.xticks(
    rotation=45,
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
);

# %%
#Let's obtain a list of all the unique ipadresses
bu = all_traffic.loc[all_traffic['Source'] == '168.167.8.167']
sns.histplot(bu['Destination'])

# %%
my_pc = all_traffic.loc[all_traffic['Source'] == '10.10.139.201'];
plt.figure(figsize=(50,10));
sns.histplot(my_pc['Destination']);
plt.xticks(
    rotation=45,
    horizontalalignment='right',
    fontweight='light',
    fontsize='x-large'  
);

# %%
ipdata.lookup('8.8.8.8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-152-10a815e7a477> in <module>
# ----> 1 ipdata.lookup('8.8.8.8')
#
# AttributeError: module 'ipdata' has no attribute 'lookup'
